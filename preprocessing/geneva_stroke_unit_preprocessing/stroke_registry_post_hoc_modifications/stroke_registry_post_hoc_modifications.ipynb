# %%
import pandas as pd
import os
import numpy as np

# %%
data_2018_path = '/Users/jk/Library/CloudStorage/Nextcloud-julian@hendrikklug․xyz/geneva_stroke_unit_dataset/stroke_registry/original_extraction/062022/SSR_cases_of_2018.xlsx'
data_2019_path = '/Users/jk/Library/CloudStorage/Nextcloud-julian@hendrikklug․xyz/geneva_stroke_unit_dataset/stroke_registry/original_extraction/062022/SSR_cases_of_2019.xlsx'
data_2020_path = '/Users/jk/Library/CloudStorage/Nextcloud-julian@hendrikklug․xyz/geneva_stroke_unit_dataset/stroke_registry/original_extraction/062022/SSR_cases_of_2020.xlsx'
data_2021_path = '/Users/jk/Library/CloudStorage/Nextcloud-julian@hendrikklug․xyz/geneva_stroke_unit_dataset/stroke_registry/original_extraction/062022/SSR_cases_of_2021.xlsx'

# %%
modifications_path = '/Users/jk/Library/CloudStorage/Nextcloud-julian@hendrikklug․xyz/geneva_stroke_unit_dataset/stroke_registry/post_hoc_modifications.xlsx'

# %%
os.path.join(os.path.dirname(os.path.dirname(data_2018_path)), 'post_hoc_modified')
# Out:
# '/Users/jk/Library/CloudStorage/Nextcloud-julian@hendrikklug․xyz/geneva_stroke_unit_dataset/stroke_registry/original_extraction/post_hoc_modified'

# %%
# skipping empty rows at the beginning
data_2018_df = pd.read_excel(data_2018_path, skiprows=[0, 1, 2, 3, 4, 5, 7])
data_2019_df = pd.read_excel(data_2019_path, skiprows=[0, 1, 2, 3, 4, 5, 7])
data_2020_df = pd.read_excel(data_2020_path, skiprows=[0, 1, 2, 3, 4, 5, 7])
data_2021_df = pd.read_excel(data_2021_path, skiprows=[0, 1, 2, 3, 4, 5, 7])

# %% [markdown]
# Verify all columns correspond

# %%
(
np.all(data_2018_df.columns == data_2019_df.columns),
np.all(data_2018_df.columns == data_2020_df.columns),
np.all(data_2018_df.columns == data_2021_df.columns)
)
# Out:
# (True, True, True)

# %%
stroke_registry_df = pd.concat([data_2018_df, data_2019_df, data_2020_df, data_2021_df])

# %%
modifications_df = pd.read_excel(modifications_path)

# %%
stroke_registry_df
# Out:
#       Unnamed: 0             Case ID      Centre  Entry date  \
# 0              1   SSR-HUG-023804235  HUG Genève    20180525
# 1              2  SSR-HUG-1002048465  HUG Genève    20181029
# 2              3  SSR-HUG-1002910806  HUG Genève    20181123
# 3              4  SSR-HUG-1005030884  HUG Genève    20181108
# 4              5  SSR-HUG-1005303803  HUG Genève    20180922
# ...          ...                 ...         ...         ...
# 1256        1257   SSR-HUG-991506305  HUG Genève    20210428
# 1257        1258  SSR-HUG-9931125546  HUG Genève    20210106
# 1258        1259  SSR-HUG-9935526604  HUG Genève    20210612
# 1259        1260  SSR-HUG-9954190962  HUG Genève    20210917
# 1260        1261   SSR-HUG-999801446  HUG Genève    20210805
#
#                   Entry person Patient refuses use of data for research  \
# 0             Emmanuel Carrera                                      yes
# 1             Emmanuel Carrera                                      NaN
# ...

# %%
modifications_df
# Out:
#                   Case ID      modified_column            new_value  \
# 0    SSR-HUG-978036574409           Onset date             20180307
# 1      SSR-HUG-3802346696        Type of event  Stroke or TIA mimic
# 2    SSR-HUG-978036574409                  Sex               Female
# 3      SSR-HUG-4070344159       IVT start date             20200107
# 4      SSR-HUG-3403543116           Onset date             20200825
# ..                    ...                  ...                  ...
# 115  SSR-HUG-971714483044        Type of event  Stroke or TIA mimic
# 116  SSR-HUG-985681686370        Type of event  Stroke or TIA mimic
# 117  SSR-HUG-972059737683  Arrival at hospital             20180105
# 118     SSR-HUG-515534935             Referral    In-hospital event
# 119    SSR-HUG-4055278341       IVT start date             20181020
#
#                                             reason
# 0                  wrong year in stroke onset date
# ...

# %%
for index, row in modifications_df.iterrows():
    print(f'Modifying {row["modified_column"]} for {row["Case ID"]}, because {row["reason"]}')
    stroke_registry_df.loc[stroke_registry_df['Case ID'] == row['Case ID'], row['modified_column']] = row['new_value']
# Out:
# Modifying Onset date for SSR-HUG-978036574409, because wrong year in stroke onset date
# Modifying Type of event for SSR-HUG-3802346696, because low flow state in patient with cardiac arrest
# Modifying Sex for SSR-HUG-978036574409, because no sex stated
# Modifying IVT start date for SSR-HUG-4070344159, because wrong year in IVT date
# Modifying Onset date for SSR-HUG-3403543116, because wrong stroke onset date
# Modifying Onset date for SSR-HUG-985513483834, because wrong year in stroke onset date
# Modifying Onset date for SSR-HUG-10557546545, because wrong year in stroke onset date
# Modifying Onset date for SSR-HUG-987214292246, because wrong year in stroke onset date
# Modifying Case ID for SSR-HUG-20015697, because wrong patient id and eds
# Modifying DOB for SSR-HUG-204632067, because wrong birth date
# Modifying Case ID for SSR-HUG-97042898, because wrong patient id and eds
# Modifying DOB for SSR-HUG-10777869400, because wrong birth date
# ...

# %%
stroke_registry_df.to_excel(os.path.join('/Users/jk/Downloads', 'stroke_registry_post_hoc_modified.xlsx'), index=False)
