# %%
import argparse
import os

import pandas as pd
import time

from preprocessing.encoding_categorical_variables.encode_categorical_variables import encode_categorical_variables
from preprocessing.handling_missing_values.impute_missing_values import impute_missing_values
from preprocessing.normalisation.normalisation import normalise_data
from preprocessing.resample_to_time_bins.resample_to_hourly_features import resample_to_hourly_features
from preprocessing.variable_assembly.variable_database_assembly import assemble_variable_database
from preprocessing.variable_assembly.relative_timestamps import transform_to_relative_timestamps

# %%
ehr_data_path ='/Users/jk1/stroke_datasets/stroke_unit_dataset/per_value/Extraction_20211110'
stroke_registry_data_path = "/Users/jk1/OneDrive - unige.ch/stroke_research/geneva_stroke_unit_dataset/data/stroke_registry/post_hoc_modified/stroke_registry_post_hoc_modified.xlsx"
patient_selection_path = '/Users/jk1/temp/opsum_extration_output/high_frequency_data_patient_selection_with_details.csv'
verbose:bool=True

# %%
# 1. Restrict to patient selection
# 2. Preprocess EHR and stroke registry variables
# 3. Restrict to variable selection
# 4. Assemble database from lab/scales/ventilation/vitals + stroke registry subparts
print('STARTING VARIABLE PREPROCESSING')
feature_df = assemble_variable_database(ehr_data_path, stroke_registry_data_path, patient_selection_path, verbose=verbose)
# Out:
# STARTING VARIABLE PREPROCESSING
# Labs measured: {'pO2', 'hémoglobine glyquée', 'Glycémie', 'Glucose', 'activité anti-Xa', 'Ph', 'Créatinine', 'Urée', 'Leucocytes', 'Sodium', 'Hématocrite', 'PTT', 'Calcium corrigé', 'Erythrocytes', 'fibrinogène', 'pO2/fiO2', 'ALAT', 'proBNP', 'bilirubine totale', 'Hémoglobine', 'Potassium', 'protéine C-réactive', 'Triglycérides', 'Thrombocytes', 'Cholestérol', 'INR', 'pCO2', 'ASAT'}
# G-Sga-pO2(T°), ABL ['kPa']
# hémoglobine glyquée ['%']
# glycémie moyenne estimée ['mmol/l']
# glucose ['mmol/l']
# Activité anti-Xa (DOAC) ['ng/ml']
# activité anti-Xa (HBPM), thérapeutique, 2x /jour ['UI/ml']
# activité anti-Xa (HNF) ['UI/ml']
# G-Sgv-pH(T°), ABL [nan]
# créatinine ['µmol/l']
# urée ['mmol/l']
# leucocytes ['G/l']
# sodium ['mmol/l']
# hématocrite ['%']
# PTT ['sec']
# calcium corrigé ['mmol/l']
# érythrocytes ['T/l']
# fibrinogène ['g/l']
# G-Sga-pO2(a,T)/FO2(I), ABL ['kPa']
# ALAT ['U/l']
# proBNP ['ng/l']
# bilirubine totale ['µmol/l']
# hémoglobine ['g/l']
# potassium ['mmol/l']
# protéine C-réactive ['mg/l']
# triglycérides ['mmol/l']
# thrombocytes ['G/l']
# cholestérol HDL ['mmol/l']
# cholestérol total ['mmol/l']
# LDL cholestérol calculé ['mmol/l']
# INR [nan]
# G-Sga-pCO2(T°), ABL ['kPa']
# ASAT ['U/l']
# Remaining non-numerical values: []
# Excluding 480 observations because out of range
#                                                   value
# dosage_label
# ALAT                                                1.0
# ASAT                                                1.0
# Activite anti-Xa (DOAC)                             1.0
# G-Sga-pCO2(T), ABL                                  3.0
# G-Sga-pO2(T), ABL                                   3.0
# G-Sga-pO2(a,T)/FO2(I), ABL                          4.0
# G-Sgv-pH(T), ABL                                    1.0
# INR                                                 2.0
# LDL cholesterol calcule                             1.0
# PTT                                                 2.0
# activite anti-Xa (HBPM), therapeutique, 2x /jour    1.0
# activite anti-Xa (HNF)                              4.0
# bilirubine totale                                   1.0
# calcium corrige                                     1.0
# cholesterol HDL                                     1.0
# cholesterol total                                   1.0
# creatinine                                          3.0
# erythrocytes                                        3.0
# fibrinogene                                         2.0
# glucose                                             2.0
# glycemie moyenne estimee                            1.0
# hematocrite                                         4.0
# hemoglobine                                         4.0
# hemoglobine glyquee                                 1.0
# leucocytes                                          3.0
# potassium                                           4.0
# proBNP                                              1.0
# proteine C-reactive                                 2.0
# sodium                                              4.0
# thrombocytes                                        3.0
# triglycerides                                       1.0
# uree                                                3.0
#                                                     count         mean  \
# dosage_label
# ALAT                                               5278.0    42.303192
# ASAT                                               5095.0    41.976251
# Activite anti-Xa (DOAC)                             280.0    98.417679
# G-Sga-pCO2(T), ABL                                 5450.0     4.976982
# G-Sga-pO2(T), ABL                                  5401.0    12.148941
# G-Sga-pO2(a,T)/FO2(I), ABL                         4870.0    39.715565
# G-Sgv-pH(T), ABL                                   2267.0     7.393882
# INR                                                7213.0     1.236807
# LDL cholesterol calcule                             877.0     2.469293
# PTT                                                7334.0    35.640701
# activite anti-Xa (HBPM), therapeutique, 2x /jour    206.0     0.747282
# activite anti-Xa (HNF)                             1360.0     0.386583
# bilirubine totale                                  6010.0    11.523087
# calcium corrige                                    3958.0     2.275958
# cholesterol HDL                                    1056.0     1.564186
# cholesterol total                                   758.0     4.349657
# creatinine                                        12215.0    93.924683
# erythrocytes                                      11266.0     4.150378
# fibrinogene                                        5197.0     3.571339
# glucose                                           11015.0     7.486400
# glycemie moyenne estimee                           2449.0     6.969212
# hematocrite                                       19311.0    36.907296
# hemoglobine                                       19261.0   122.744354
# hemoglobine glyquee                                2451.0     6.016279
# leucocytes                                        11256.0     9.459408
# potassium                                         19877.0     3.927922
# proBNP                                             2797.0  2261.466214
# proteine C-reactive                                6270.0    43.402638
# sodium                                            20155.0   139.725229
# thrombocytes                                      11291.0   239.714994
# triglycerides                                      2706.0     1.393599
# uree                                              11796.0     7.214564
#
#                                                           std      min  \
# dosage_label
# ALAT                                               170.050942    4.750
# ASAT                                               134.199314    6.000
# Activite anti-Xa (DOAC)                            111.878419    0.000
# G-Sga-pCO2(T), ABL                                   0.895229    1.430
# G-Sga-pO2(T), ABL                                    7.502710    4.020
# G-Sga-pO2(a,T)/FO2(I), ABL                          13.105975    4.000
# G-Sgv-pH(T), ABL                                     0.057005    6.840
# INR                                                  0.649202    0.930
# LDL cholesterol calcule                              1.063148    0.180
# PTT                                                 18.385822   17.200
# activite anti-Xa (HBPM), therapeutique, 2x /jour     0.370701    0.000
# activite anti-Xa (HNF)                               0.267265    0.000
# bilirubine totale                                    8.407938    1.000
# calcium corrige                                      0.131096    1.480
# cholesterol HDL                                      9.846960    0.460
# cholesterol total                                    1.151110    1.500
# creatinine                                          69.975021   19.000
# erythrocytes                                         0.769233    0.990
# fibrinogene                                          1.404187    0.300
# glucose                                              2.443349    1.300
# glycemie moyenne estimee                             1.920393    3.800
# hematocrite                                          7.004696    6.500
# hemoglobine                                         24.271970   25.000
# hemoglobine glyquee                                  1.209743    4.000
# leucocytes                                           5.727751    0.100
# potassium                                            0.515552    0.900
# proBNP                                            5536.205355    5.000
# proteine C-reactive                                 63.476041    0.285
# sodium                                               4.350001  108.000
# thrombocytes                                        98.139233    5.000
# triglycerides                                        0.866180    0.320
# uree                                                 4.867906    1.100
#
#                                                        25%      50%      75%  \
# dosage_label
# ALAT                                               15.0000   21.000    33.00
# ASAT                                               19.0000   25.000    35.00
# Activite anti-Xa (DOAC)                            10.0000   53.000   154.25
# G-Sga-pCO2(T), ABL                                  4.4400    4.890     5.42
# G-Sga-pO2(T), ABL                                   8.8400   10.100    11.80
# G-Sga-pO2(a,T)/FO2(I), ABL                         31.0000   40.300    47.90
# G-Sgv-pH(T), ABL                                    7.3700    7.400     7.43
# INR                                                 1.0000    1.040     1.15
# LDL cholesterol calcule                             1.6700    2.340     3.15
# PTT                                                26.9000   30.100    36.50
# activite anti-Xa (HBPM), therapeutique, 2x /jour    0.4925    0.755     0.98
# activite anti-Xa (HNF)                              0.2300    0.350     0.47
# bilirubine totale                                   6.0000    9.000    14.00
# calcium corrige                                     2.2000    2.270     2.35
# cholesterol HDL                                     0.9800    1.210     1.48
# cholesterol total                                   3.6000    4.300     5.10
# creatinine                                         64.0000   79.000   100.00
# erythrocytes                                        3.6300    4.200     4.68
# fibrinogene                                         2.7000    3.400     4.20
# glucose                                             5.9000    7.000     8.40
# glycemie moyenne estimee                            5.9000    6.400     7.20
# hematocrite                                        32.0000   37.500    41.80
# hemoglobine                                       105.0000  125.000   140.00
# hemoglobine glyquee                                 5.4000    5.700     6.20
# leucocytes                                          6.6000    8.500    11.00
# potassium                                           3.6000    3.900     4.20
# proBNP                                            166.0000  560.000  1888.00
# proteine C-reactive                                 3.6000   17.100    54.20
# sodium                                            137.0000  140.000   142.00
# thrombocytes                                      180.0000  225.000   283.00
# triglycerides                                       0.9000    1.190     1.63
# uree                                                4.4000    6.000     8.20
#
#                                                          max
# dosage_label
# ALAT                                               4533.0000
# ASAT                                               4381.0000
# Activite anti-Xa (DOAC)                             497.7000
# G-Sga-pCO2(T), ABL                                   11.1000
# G-Sga-pO2(T), ABL                                    74.2000
# G-Sga-pO2(a,T)/FO2(I), ABL                           99.7000
# G-Sgv-pH(T), ABL                                      7.6500
# INR                                                  11.5500
# LDL cholesterol calcule                               6.5100
# PTT                                                 168.0000
# activite anti-Xa (HBPM), therapeutique, 2x /jour      1.6800
# activite anti-Xa (HNF)                                1.3755
# bilirubine totale                                   109.0000
# calcium corrige                                       3.0800
# cholesterol HDL                                     321.0000
# cholesterol total                                     8.7000
# creatinine                                         1578.0000
# erythrocytes                                          7.1600
# fibrinogene                                          11.5500
# glucose                                              46.0000
# glycemie moyenne estimee                             19.2000
# hematocrite                                          64.8000
# hemoglobine                                         208.0000
# hemoglobine glyquee                                  13.7000
# leucocytes                                          165.1000
# potassium                                            14.0000
# proBNP                                            73500.0000
# proteine C-reactive                                 489.4000
# sodium                                              165.0000
# thrombocytes                                       1362.0000
# triglycerides                                        16.6300
# uree                                                 50.2000
# Preprocessing NIHSS
# Excluding 1 observations because out of range
# Glasgow Coma Scale
# Excluding 19 observations because out of range
# FIO2:
# Excluding 33 observations because out of range
# SPO2:
# Excluding 78 observations because out of range
# Preprocessing temperature
# Excluding 22 observations because out of range
# Preprocessing systolic blood pressure
# Excluding 51 observations because out of range
# Preprocessing diastolic blood pressure
# Excluding 66 observations because out of range
# Preprocessing mean blood pressure
# Excluding 288 observations because out of range
# Preprocessing heart rate
# Excluding 188 observations because out of range
# Preprocessing respiratory rate
# Excluding 29768 observations because out of range
# Preprocessing oxygen saturation
# Excluding 77 observations because out of range
# Preprocessing weight
# Excluding 22 observations because out of range
# Number of patients after selection: 2865
# Number of patients not selected: 58
# Number of patients from selection that were not found: 442
# Dropping 65 cases because sampling start date too early
# Dropping 10 cases because sampling start date too late
# Number of patients after selection: 2790
# Preprocessing stroke registry_data
# Number of patients after selection: 3307
# Number of patients not selected: 1857
# Number of patients from selection that were not found: 0
# Excluding 418 observations because out of range
# Excluding 7 observations because out of range
# Excluding 3 observations because out of range
# Excluding 4 observations because out of range
# Excluding 127 observations because out of range
# Excluding 110 observations because out of range
# Number of cases from EHR data (after restriction to patient selection) not found in registry: 0
# Number of cases from registry not found in EHR data: 519

# %%
feature_df.head()

# %%
feature_df[feature_df.value.isna()].sample_label.unique()

# %%
feature_df.case_admission_id.nunique()
# Out:
# 2788

# %%
# 5. Transform timestamps to relative timestamps from first measure
# 6. Restrict to time range
print('TRANSFORMING TO RELATIVE TIME AND RESTRICTING TIME RANGE')
restricted_feature_df = transform_to_relative_timestamps(feature_df, drop_old_columns=False,
                                                             restrict_to_time_range=True, desired_time_range=72,
                                                             enforce_min_time_range=True, min_time_range=12)

# %%
restricted_feature_df.head()

# %%
restricted_feature_df[restricted_feature_df.value.isna()].sample_label.unique()

# %%
restricted_feature_df.case_admission_id.nunique()

# %%
# 7. Encoding categorical variables (one-hot)
print('ENCODING CATEGORICAL VARIABLES')
cat_encoded_restricted_feature_df = encode_categorical_variables(restricted_feature_df, verbose=verbose)

# %%
cat_encoded_restricted_feature_df.head()

# %%
cat_encoded_restricted_feature_df[cat_encoded_restricted_feature_df.value.isna()].sample_label.unique()

# %%
cat_encoded_restricted_feature_df.case_admission_id.nunique()

# %%
# 8. Resampling to hourly frequency
print('RESAMPLING TO HOURLY FREQUENCY')
resampled_df = resample_to_hourly_features(cat_encoded_restricted_feature_df, verbose=verbose)

# %%
resampled_df.head()

# %%
resampled_df[resampled_df.value.isna()].sample_label.unique()

# %%
resampled_df.case_admission_id.nunique()

# %%
# 9. imputation of missing values
print('IMPUTING MISSING VALUES')
imputed_missing_df = impute_missing_values(resampled_df, verbose=verbose)

# %%
imputed_missing_df.head()

# %%
imputed_missing_df[imputed_missing_df.value.isna()]

# %%
imputed_missing_df.case_admission_id.nunique()

# %%
# 10. normalisation
print('APPLYING NORMALISATION')
normalised_df = normalise_data(imputed_missing_df, verbose=verbose)

# %%
normalised_df.head(1000)

# %%
normalised_df[normalised_df.value.isna()].sample_label.unique()

# %%
len(normalised_df.case_admission_id.unique())

# %%
imputed_missing_df[imputed_missing_df.sample_label == 'FIO2'].describe()

# %%
temp = imputed_missing_df[imputed_missing_df.sample_label == 'FIO2'].value.copy()

# %%
temp.quantile(0.25) - 1.5 * (temp.quantile(0.75) - temp.quantile(0.25))

# %%
temp.quantile(0.25) - 1.5 * (temp.quantile(0.75) - temp.quantile(0.25)) == temp.quantile(0.75) + 1.5 * (temp.quantile(0.75) - temp.quantile(0.25))

# %%
temp = temp.clip(lower=temp.quantile(0.25) - 1.5 * (temp.quantile(0.75) - temp.quantile(0.25) - temp.median()/1000),
                 upper=temp.quantile(0.75) + 1.5 * (temp.quantile(0.75) - temp.quantile(0.25)))

# %%
temp.describe()

# %%
imputed_missing_df[imputed_missing_df.sample_label == 'Glasgow Coma Scale'].describe()

# %%
save_file_prefix:str = 'preprocessed_data'
output_dir = '/Users/jk1/temp/opsum_prepro_output'

# %%
timestamp = time.strftime("%d%m%Y_%H%M%S")
save_path = os.path.join(output_dir, f'{save_file_prefix}_{timestamp}.csv')

# %%
# normalised_df.to_csv(save_path)
